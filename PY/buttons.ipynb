# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual, fixed
from random import choice
from onderdelen import start_config as c
import matplotlib.pyplot as plt
import numpy as np
from IPython import display as d
#from vpython import *
    
Layout = widgets.Layout
Box = widgets.Box
VBox = widgets.VBox
HBox = widgets.HBox
Button = widgets.Button
Out = widgets.Output(layout=Layout(flex='1 1 auto', width='auto'))

# %%
lang = 'EN'
print('language'+lang)   
#Kast dimensies

if lang == 'EN':
    lang_k='Cupboard dimensions'
elif lang == 'NL':
    lang_k='Kast afmetingen'
elif lang == 'DE':
    lang_k='Schrankabmessungen'

if lang == 'EN':
    lang_kb='Width (cm): '
elif lang == 'NL':
    lang_kb='Breedte (cm) (cm): '
elif lang == 'DE':
    lang_kb='Breite (cm): '

if lang == 'EN':
    lang_kh='Height (cm): '
elif lang == 'NL':
    lang_kh='Hoogte (cm): '
elif lang == 'DE':
    lang_kh='Höhe (cm): '

if lang == 'EN':
    lang_kd='Depth (cm): '
elif lang == 'NL':
    lang_kd='Diepte (cm): '
elif lang == 'DE':
    lang_kd='Tiefe (cm): '

#Plank dimensies

if lang == 'EN':
    lang_p='Plank dimensions'
elif lang == 'NL':
    lang_p='Plank afmetingen'
elif lang == 'DE':
    lang_p='Regalabmessungen'

if lang == 'EN':
    lang_pb='Width (cm): '
elif lang == 'NL':
    lang_pb='Breedte (cm): '
elif lang == 'DE':
    lang_pb='Breite (cm): '

if lang == 'EN':
    lang_ph='Height (cm): '
elif lang == 'NL':
    lang_ph='Hoogte (cm): '
elif lang == 'DE':
    lang_ph='Höhe (cm): '

if lang == 'EN':
    lang_pd='Depth (cm): '
elif lang == 'NL':
    lang_pd='Diepte (cm): '
elif lang == 'DE':
    lang_pd='Tiefe (cm): '

#Voeten dimensies

if lang == 'EN':
    lang_v='Feet dimensions'
elif lang == 'NL':
    lang_v='Voet afmetingen'
elif lang == 'DE':
    lang_v='Fußabmessungen'

if lang == 'EN':
    lang_vh='Height (cm): '
elif lang == 'NL':
    lang_vh='Hoogte (cm): '
elif lang == 'DE':
    lang_vh='Höhe (cm): '

#Model interacties

if lang == 'EN':
    model_i='Model interactions'
elif lang == 'NL':
    model_i='Model interacties'
elif lang == 'DE':
    model_i='Interaktionen modellieren'

if lang == 'EN':
    lang_build='Build'
elif lang == 'NL':
    lang_build='Bouw'
elif lang == 'DE':
    lang_build='Bauen'

if lang == 'EN':
    lang_buy='Buy'
elif lang == 'NL':
    lang_buy='Kopen'
elif lang == 'DE':
    lang_buy='Kaufen'

if lang == 'EN':
    lang_reset='Reset'
elif lang == 'NL':
    lang_reset='Reset'
elif lang == 'DE':
    lang_reset='Zurücksetzen'

if lang == 'EN':
    lang_add_plank='Add plank'
elif lang == 'NL':
    lang_add_plank='Plank toevoegen'
elif lang == 'DE':
    lang_add_plank='Regal hinzufügen'

if lang == 'EN':
    deur_gesloten='Door closed'
elif lang == 'NL':
    deur_gesloten='Deur gesloten'
elif lang == 'DE':
    deur_gesloten='Tür geschlossen'

if lang == 'EN':
    deur_open='Door open'
elif lang == 'NL':
    deur_open='Deur open'
elif lang == 'DE':
    deur_open='Tür öffen'

if lang == 'EN':
    deur_weg='Door gone'
elif lang == 'NL':
    deur_weg='Deur weg'
elif lang == 'DE':
    deur_weg='Tür weg'
# Out:
# languageEN

# %%
outer_dimensions=[widgets.HTML(
    value=f"<center><b>{lang_k}</b></center>",
    layout=Layout(flex='1 1 auto', width='auto')
)]

kast_w=widgets.FloatText(
    value=c.kast_breedte,
    min=0,
    step=0.1,
    description=lang_kb,
    disabled=False,
    layout=Layout(flex='1 1 auto', width='auto')
)

kast_h=widgets.FloatText(
    value=c.kast_hoogte,
    min=0,
    step=0.1,
    description=lang_kh,
    disabled=False,
    layout=Layout(flex='1 1 auto', width='auto')
)

kast_d=widgets.FloatText(
    value=c.kast_diepte,
    min=0,
    step=0.1,
    description=lang_kd,
    disabled=False,
    layout=Layout(flex='1 1 auto', width='auto')
)

kast = [kast_w,kast_h,kast_d]

plank_dimensions=[widgets.HTML(
    value=f"<center><b>{lang_p}</b></center>",
    layout=Layout(flex='1 1 auto', width='auto')
)]

plank_w=widgets.FloatText(
    value=c.plank_breedte,
    min=0,
    step=0.1,
    description=lang_pb,
    disabled=False,
    layout=Layout(flex='1 1 auto', width='auto')
)

plank_h=widgets.FloatText(
    value=c.plank_hoogte,
    min=0,
    step=0.1,
    description=lang_ph,
    disabled=False,
    layout=Layout(flex='1 1 auto', width='auto')
)

plank_d=widgets.FloatText(
    value=c.plank_lengte,
    min=0,
    step=0.1,
    description=lang_pd,
    disabled=False,
    layout=Layout(flex='1 1 auto', width='auto')
)

plank = [plank_w,plank_h,plank_d]

feet_dimensions=[widgets.HTML(
    value=f"<center><b>{lang_v}</b></center>",
    layout=Layout(flex='1 1 auto', width='auto')
)]

feet_h=[widgets.FloatText(
    value=c.voet_hoogte,
    min=0,
    step=0.1,
    description=lang_vh,
    disabled=False,
    layout=Layout(flex='1 1 auto', width='auto')
)]

model_interactions=[widgets.HTML(
    value=f"<center><b>{model_i}</b></center>",
    layout=Layout(flex='1 1 auto', width='auto')
)]

error_log=[widgets.HTML(
    value=f"<center><b>{c.error}</b></center>",
    layout=Layout(flex='1 1 auto', width='auto')
)]

build = widgets.Button(
    description=lang_build,
    disabled=c.build_d,
    button_style='',
    layout=Layout(flex='1 1 auto', width='auto')
)

buy = widgets.Button(
    description=lang_buy,
    disabled=c.buy_d,
    button_style='',
    layout=Layout(flex='1 1 auto', width='auto')
)

reset = widgets.Button(
    description=lang_reset,
    disabled=c.reset_d,
    button_style='',
    layout=Layout(flex='1 1 auto', width='auto')
)

add = widgets.Button(
    description=lang_add_plank,
    disabled=c.add_plank_d,
    button_style='',
    layout=Layout(flex='1 1 auto', width='auto')
)

buttons=[build,buy,reset,add]

door_c = widgets.Button(
    description=deur_gesloten,
    disabled=c.door_c_d,
    button_style='',
    layout=Layout(flex='1 1 auto', width='auto')
)

door_o = widgets.Button(
    description=deur_open,
    disabled=c.door_o_d,
    button_style='',
    layout=Layout(flex='1 1 auto', width='auto')
)

door_g = widgets.Button(
    description=deur_weg,
    disabled=c.door_g_d,
    button_style='',
    layout=Layout(flex='1 1 auto', width='auto')
)

door_state=[door_c,door_o,door_g]

space=widgets.HTML(
    value=' ',
    layout=Layout(flex='1 1 auto', width='auto')
)

# %%
@build.on_click
def BUILD(b):
    print(kast_w.value)
    print(kast_h.value)
    print(kast_d.value)
    c.buy_d = False
    buy.disabled == False
    
@buy.on_click
def BUY(b):
    print('BUY')
    
@reset.on_click
def BUY(b):
    print('RESET')
    
@add.on_click
def BUY(b):
    print('ADD')

# %%
# %matplotlib widget
plt.rcParams['figure.dpi'] = 72
plt.rcParams['figure.figsize'] = 13,13

with Out:
    fig = plt.figure()
    fig.canvas.layout.width = '100%'
    fig.canvas.header_visible = False
    ax = fig.add_subplot(projection='3d')
    # Hide grid lines
    ax.grid(False)

    # Hide axes ticks
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])

    xs = ()
    ys = ()
    zs = ()
    ax.scatter(xs, ys, zs, depthshade=0)

    ax.set_xlabel('diepte')
    ax.set_ylabel('breedte')
    ax.set_zlabel('hoogte')

    #d.display(plt.show())
# Out:
# Canvas(header_visible=False, layout=Layout(width='100%'), toolbar=Toolbar(toolitems=[('Home', 'Reset original …

# %%
box_layout = Layout(display='flex',
                    flex_flow='row',
                    align_items='stretch',
                    width='100%')

row1 =  Box(children=outer_dimensions, layout=box_layout)
row2 =  Box(children=kast, layout=box_layout)
row3 =  Box(children=plank_dimensions, layout=box_layout)
row4 =  Box(children=plank, layout=box_layout)
row5 =  Box(children=feet_dimensions, layout=box_layout)
row6 =  Box(children=feet_h, layout=box_layout)
row7 =  Box(children=model_interactions, layout=box_layout)
row8 =  Box(children=buttons, layout=box_layout)
row9 =  Box(children=door_state, layout=box_layout)
row10 = Box(children=error_log, layout=box_layout)
row11 = HBox([space,Out,space])

VBox([row1,row2,row3,row4,row5,row6,row7,row8,row9,row10,row11])
